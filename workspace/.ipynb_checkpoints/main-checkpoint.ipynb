# %%
# Group: Daniel Martín Cruz, Ion Bueno Ulacia

# %%
import loader_covid as ldr
# Out:
# /home/ion/Programas/miniconda3/envs/pyt-cpu/lib/python3.7/site-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /home/ion/Programas/miniconda3/envs/pyt-cpu/lib/python3.7/site-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)

# %%
# Global visualization
ldr.Loader_Covid(True).plot_world_map() #it updates dataset

# %%
# New loader
loader = ldr.Loader_Covid()
#Locations: [Country_Region, AdminRegion1, AdminRegion2]
locations = [['United States', 'Florida', 'Miami-Dade County'],
             ['Germany', 'Bavaria', ''],
             ['Brazil', '', ''],
             ['Worldwide', '', '']]

# %%
# Data loading
data_dict = loader.load(locations)
loader.plots()
# Out:
# [<matplotlib.axes._subplots.AxesSubplot at 0x7f3436724410>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f34366b1510>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f3436544550>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f343647c410>]

# %%
# Data forecasting
data_split_dict = loader.split_data(target='Confirmed') #test_split, target: Confirmed, Deaths, Recovered
loader.forecasting() #steps = future prediction
# Out:
# [<matplotlib.axes._subplots.AxesSubplot at 0x7f34365b1b50>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f3438103c50>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f3436636290>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f3437fe01d0>]

# %%
# Diagnostics of residuals
figures_list = loader.diagnostics()
print(figures_list[0].axes)
# Out:
# [<matplotlib.axes._subplots.AxesSubplot object at 0x7f343879d450>, <matplotlib.axes._subplots.AxesSubplot object at 0x7f3436350d90>, <matplotlib.axes._subplots.AxesSubplot object at 0x7f343854df90>, <matplotlib.axes._subplots.AxesSubplot object at 0x7f34386335d0>]
